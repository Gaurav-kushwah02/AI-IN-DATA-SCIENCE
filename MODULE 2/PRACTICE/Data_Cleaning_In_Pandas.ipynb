# %% [markdown]
# # Data Cleaning in pandas

# %%
#important libraries
import pandas as pd

# %%
#Upload DataSet for cleaning
data=pd.read_csv('/content/Messy_Employment_India_Dataset.csv')

# %% [markdown]
# #View Dataset

# %%
data.head()      #it gives first 5 rows by default
#data.tail()      #it gives last 5 rows by default
# Out:
#        Status Age Group    Education    Industry   Location   AI Risk  \
# 0    EMPLOYED     25_34  high school  Technology      Urban       NaN
# 1    EMPLOYED     18-24      Diploma     Fintech      rural  moderate
# 2    EMPLOYED     25_34  High School      Retail      Delhi       Low
# 3  UNEMPLOYED     18-24      Masters      Retail      Urban       Low
# 4         NaN     45-54      Diploma     Fintech  Hyderabad       low
#
#    Years of Experience  Monthly Salary (INR) Date Recorded
# 0                  NaN               40700.0      1/1/2023
# 1                  NaN               17500.0      1/2/2023
# 2                 16.0               77600.0      1/3/2023
# 3                 30.0              100200.0      1/4/2023
# 4                  9.0               19500.0      1/5/2023

# %%
data.info()        #it gives all data including int float str
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Status                1732 non-null   object
#  1   Age Group             1768 non-null   object
#  2   Education             1804 non-null   object
#  3   Industry              1799 non-null   object
#  4   Location              1787 non-null   object
#  5   AI Risk               1716 non-null   object
#  6   Years of Experience   980 non-null    float64
#  7   Monthly Salary (INR)  1613 non-null   float64
#  8   Date Recorded         2000 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 140.8+ KB

# %%
data.describe()      #it describes only int values
# Out:
#        Years of Experience  Monthly Salary (INR)
# count           980.000000           1613.000000
# mean             15.244898          76886.360818
# std               9.103941          41628.008054
# min               0.000000           5100.000000
# 25%               7.000000          40700.000000
# 50%              16.000000          77200.000000
# 75%              23.000000         112400.000000
# max              30.000000         149900.000000

# %%
data.shape                 #it gives total rows and columns in data
                           #no need of brackets()
# Out:
# (2000, 9)

# %% [markdown]
# # MISSING VALUE

# %%
data.isnull()    #to check missing value, true is missing false if data is filled.
# Out:
#       Status  Age Group  Education  Industry  Location  AI Risk  \
# 0      False      False      False     False     False     True
# 1      False      False      False     False     False    False
# 2      False      False      False     False     False    False
# 3      False      False      False     False     False    False
# 4       True      False      False     False     False    False
# ...      ...        ...        ...       ...       ...      ...
# 1995   False      False      False     False     False    False
# 1996   False      False      False     False      True     True
# 1997    True      False      False     False      True    False
# 1998   False      False      False     False     False    False
# 1999   False      False      False      True      True    False
#
#       Years of Experience  Monthly Salary (INR)  Date Recorded
# 0                    True                 False          False
# 1                    True                 False          False
# ...

# %%
data.isnull().sum()         #sum up all the null space
# Out:
# Status                   268
# Age Group                232
# Education                196
# Industry                 201
# Location                 213
# AI Risk                  284
# Years of Experience     1020
# Monthly Salary (INR)     387
# Date Recorded              0
# dtype: int64

# %% [markdown]
# # HANDLING MISSING VALUES
# ### fillna()..this func for filling value inside it at empty space

# %%
#replacing all null space by finding mean of it.
data['Years of Experience'] = data['Years of Experience'].fillna(data['Years of Experience'].mean())
data
# Out:
#           Status Age Group    Education    Industry   Location   AI Risk  \
# 0       EMPLOYED     25_34  high school  Technology      Urban       NaN
# 1       EMPLOYED     18-24      Diploma     Fintech      rural  moderate
# 2       EMPLOYED     25_34  High School      Retail      Delhi       Low
# 3     UNEMPLOYED     18-24      Masters      Retail      Urban       Low
# 4            NaN     45-54      Diploma     Fintech  Hyderabad       low
# ...          ...       ...          ...         ...        ...       ...
# 1995    employed     25-34         Ph.D     Finance  Hyderabad       Low
# 1996    EMPLOYED     25-34          PhD       Tech         NaN       NaN
# 1997         NaN   35 - 44      Masters   Education        NaN       low
# 1998    EMPLOYED     25_34  high school      Retail     Mumbai      HIGH
# 1999  UNEMPLOYED     25_34  High School         NaN        NaN  moderate
#
#       Years of Experience  Monthly Salary (INR) Date Recorded
# ...

# %%
#replacing null value by word
data['Status']=data['Status'].fillna('UNKNOWN')
data
# Out:
#           Status Age Group    Education    Industry   Location   AI Risk  \
# 0       EMPLOYED     25_34  high school  Technology      Urban       NaN
# 1       EMPLOYED     18-24      Diploma     Fintech      rural  moderate
# 2       EMPLOYED     25_34  High School      Retail      Delhi       Low
# 3     UNEMPLOYED     18-24      Masters      Retail      Urban       Low
# 4        UNKNOWN     45-54      Diploma     Fintech  Hyderabad       low
# ...          ...       ...          ...         ...        ...       ...
# 1995    employed     25-34         Ph.D     Finance  Hyderabad       Low
# 1996    EMPLOYED     25-34          PhD       Tech         NaN       NaN
# 1997     UNKNOWN   35 - 44      Masters   Education        NaN       low
# 1998    EMPLOYED     25_34  high school      Retail     Mumbai      HIGH
# 1999  UNEMPLOYED     25_34  High School         NaN        NaN  moderate
#
#       Years of Experience  Monthly Salary (INR) Date Recorded
# ...

# %% [markdown]
# # REMOVE DUPLICATES IN DATASET

# %%
#it removes the duplicate rows
data.drop_duplicates()
data
# Out:
#           Status Age Group    Education    Industry   Location   AI Risk  \
# 0       EMPLOYED     25_34  high school  Technology      Urban       NaN
# 1       EMPLOYED     18-24      Diploma     Fintech      rural  moderate
# 2       EMPLOYED     25_34  High School      Retail      Delhi       Low
# 3     UNEMPLOYED     18-24      Masters      Retail      Urban       Low
# 4        UNKNOWN     45-54      Diploma     Fintech  Hyderabad       low
# ...          ...       ...          ...         ...        ...       ...
# 1995    employed     25-34         Ph.D     Finance  Hyderabad       Low
# 1996    EMPLOYED     25-34          PhD       Tech         NaN       NaN
# 1997     UNKNOWN   35 - 44      Masters   Education        NaN       low
# 1998    EMPLOYED     25_34  high school      Retail     Mumbai      HIGH
# 1999  UNEMPLOYED     25_34  High School         NaN        NaN  moderate
#
#       Years of Experience  Monthly Salary (INR) Date Recorded
# ...

# %% [markdown]
# # Check And Fix Data type

# %%
#o check data type of every group
data.dtypes
# Out:
# Status                   object
# Age Group                object
# Education                object
# Industry                 object
# Location                 object
# AI Risk                  object
# Years of Experience     float64
# Monthly Salary (INR)    float64
# Date Recorded            object
# dtype: object

# %%
#To change the data type
#data['Age Group'] = data['Age Group'].astype(int)

# %% [markdown]
# # Rename The Columns

# %%
#it will change the column heading, We can change multiple name at a time just by using "," in curly braces
data=data.rename(columns={'Age Group':'Age'})
data
# Out:
#           Status      Age    Education    Industry   Location   AI Risk  \
# 0       EMPLOYED    25_34  high school  Technology      Urban       NaN
# 1       EMPLOYED    18-24      Diploma     Fintech      rural  moderate
# 2       EMPLOYED    25_34  High School      Retail      Delhi       Low
# 3     UNEMPLOYED    18-24      Masters      Retail      Urban       Low
# 4        UNKNOWN    45-54      Diploma     Fintech  Hyderabad       low
# ...          ...      ...          ...         ...        ...       ...
# 1995    employed    25-34         Ph.D     Finance  Hyderabad       Low
# 1996    EMPLOYED    25-34          PhD       Tech         NaN       NaN
# 1997     UNKNOWN  35 - 44      Masters   Education        NaN       low
# 1998    EMPLOYED    25_34  high school      Retail     Mumbai      HIGH
# 1999  UNEMPLOYED    25_34  High School         NaN        NaN  moderate
#
#       Years of Experience  Monthly Salary (INR) Date Recorded
# ...

# %% [markdown]
# # Handle Outliers (Simple Filtering by using conditions)

# %%
#it will sort data based on condition
data_sort=data[data['Monthly Salary (INR)']<10000]
data_sort
# Out:
#           Status       Age    Education    Industry   Location   AI Risk  \
# 41      employed     25-34   Bachelor's     Fintech      Delhi       Low
# 97      Employed     25_34         Ph.D         NaN      urban      High
# 114     Employed     25-34      Masters   Education   suburban       low
# 118      UNKNOWN     25_34          NaN     Finance      Urban    Medium
# 141     EMPLOYED     18-24      Diploma  Healthcare      Delhi      HIGH
# 221      UNKNOWN   35 - 44      Diploma       Tech      Mumbai       Low
# 224      UNKNOWN  18 to 24          NaN  Technology      Urban      HIGH
# 235   unemployed       NaN       Master      Retail      urban  moderate
# 237     employed     45-54          NaN   Education     Mumbai       Low
# 269     employed     25_34          PhD      Retail   suburban       Low
# 280     Employed     45-54    Bachelors       Tech    suburban       low
# 338   UNEMPLOYED     18-24          NaN      Retail      urban       NaN
# ...

# %% [markdown]
# # Clean Text Data

# %%
#Removes extra spaces from the beginning and end
data['Education'] = data['Education'].str.strip()
data
# Out:
#           Status      Age    Education    Industry   Location   AI Risk  \
# 0       EMPLOYED    25_34  high school  Technology      Urban       NaN
# 1       EMPLOYED    18-24      Diploma     Fintech      rural  moderate
# 2       EMPLOYED    25_34  High School      Retail      Delhi       Low
# 3     UNEMPLOYED    18-24      Masters      Retail      Urban       Low
# 4        UNKNOWN    45-54      Diploma     Fintech  Hyderabad       low
# ...          ...      ...          ...         ...        ...       ...
# 1995    employed    25-34         Ph.D     Finance  Hyderabad       Low
# 1996    EMPLOYED    25-34          PhD       Tech         NaN       NaN
# 1997     UNKNOWN  35 - 44      Masters   Education        NaN       low
# 1998    EMPLOYED    25_34  high school      Retail     Mumbai      HIGH
# 1999  UNEMPLOYED    25_34  High School         NaN        NaN  moderate
#
#       Years of Experience  Monthly Salary (INR) Date Recorded
# ...

# %%
#Converts all city names to lowercase letters.
data['Location'] = data['Location'].str.lower()
data
# Out:
#           Status      Age    Education    Industry   Location   AI Risk  \
# 0       EMPLOYED    25_34  high school  Technology      urban       NaN
# 1       EMPLOYED    18-24      Diploma     Fintech      rural  moderate
# 2       EMPLOYED    25_34  High School      Retail      delhi       Low
# 3     UNEMPLOYED    18-24      Masters      Retail      urban       Low
# 4        UNKNOWN    45-54      Diploma     Fintech  hyderabad       low
# ...          ...      ...          ...         ...        ...       ...
# 1995    employed    25-34         Ph.D     Finance  hyderabad       Low
# 1996    EMPLOYED    25-34          PhD       Tech         NaN       NaN
# 1997     UNKNOWN  35 - 44      Masters   Education        NaN       low
# 1998    EMPLOYED    25_34  high school      Retail     mumbai      HIGH
# 1999  UNEMPLOYED    25_34  High School         NaN        NaN  moderate
#
#       Years of Experience  Monthly Salary (INR) Date Recorded
# ...

# %% [markdown]
# # DATA  VALIDATION

# %%
#it will show data of those have YOE more than 10 year
data=data[data['Years of Experience']>10]
data
# Out:
#           Status      Age    Education    Industry   Location   AI Risk  \
# 0       EMPLOYED    25_34  high school  Technology      urban       NaN
# 1       EMPLOYED    18-24      Diploma     Fintech      rural  moderate
# 2       EMPLOYED    25_34  High School      Retail      delhi       Low
# 3     UNEMPLOYED    18-24      Masters      Retail      urban       Low
# 5     Unemployed    25_34          PhD       Tech   bangalore      HIGH
# ...          ...      ...          ...         ...        ...       ...
# 1995    employed    25-34         Ph.D     Finance  hyderabad       Low
# 1996    EMPLOYED    25-34          PhD       Tech         NaN       NaN
# 1997     UNKNOWN  35 - 44      Masters   Education        NaN       low
# 1998    EMPLOYED    25_34  high school      Retail     mumbai      HIGH
# 1999  UNEMPLOYED    25_34  High School         NaN        NaN  moderate
#
#       Years of Experience  Monthly Salary (INR) Date Recorded
# ...

# %%
#it will show data acc to condition
#data = data[(data['Age'] > 0) & (data['Age'] <= 120)]

# %% [markdown]
# # To save the clean or modified file

# %%
data.to_csv("cleared data.csv",index=False)
